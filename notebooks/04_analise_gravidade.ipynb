# %% [markdown]
# # Análise de gravidade
#
# Observa mortos, feridos graves e acidentes graves.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

# %%
import pandas as pd
from src.config import TRATADOS_DIR
df = pd.read_csv(TRATADOS_DIR / 'ocorrencias_tratadas.csv', sep=';', encoding='utf-8-sig')
df[df['acidente_grave'] == 'Sim'].groupby('uf').size().sort_values(ascending=False).head(10)
