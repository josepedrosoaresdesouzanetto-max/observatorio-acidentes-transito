# %% [markdown]
# # Limpeza e tratamento
#
# Executa o tratamento e confere colunas derivadas.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.limpar_dados import gerar_tratados
ocorrencias, pessoas = gerar_tratados()
ocorrencias[['ano','mes','hora','faixa_horario','total_feridos','total_vitimas','acidente_grave']].head()
