# %% [markdown]
# # Entendimento dos dados
#
# Carrega amostras das bases brutas e verifica colunas, anos e tipos de arquivo.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.carregar_dados import carregar_dados
ocorrencias = carregar_dados('ocorrencia', anos=(2024, 2025, 2026))
pessoas = carregar_dados('pessoa', anos=(2024, 2025, 2026))
print(ocorrencias.shape, pessoas.shape)
ocorrencias.head()
